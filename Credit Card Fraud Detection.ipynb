# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from keras import layers
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
sns.set_style('whitegrid')

# %%
df = pd.read_csv('./data/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %% [markdown]
# ## Data pre-processing

# %% [markdown]
# ### Duplicate values

# %%
df.duplicated().sum()
# Out:
# 1081

# %%
df.drop_duplicates(inplace=True)

# %%
df['Class'].value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %%
df.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# 25%        -0.850134      -0.689830      -0.769031      -0.552509
# 50%        -0.022248      -0.053468      -0.275168       0.040859
# 75%         0.739647       0.612218       0.396792       0.570474
# max        16.875344      34.801666      73.301626     120.589494
#
#                   V8             V9  ...            V21            V22  \
# count  283726.000000  283726.000000  ...  283726.000000  283726.000000
# mean       -0.000854      -0.001596  ...      -0.000371      -0.000015
# std         1.179054       1.095492  ...       0.723909       0.724550
# min       -73.216718     -13.434066  ...     -34.830382     -10.933144
# 25%        -0.208828      -0.644221  ...      -0.228305      -0.542700
# 50%         0.021898      -0.052596  ...      -0.029441       0.006675
# 75%         0.325704       0.595977  ...       0.186194       0.528245
# max        20.007208      15.594995  ...      27.202839      10.503090
#
#                  V23            V24            V25            V26  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean        0.000198       0.000214      -0.000232       0.000149
# std         0.623702       0.605627       0.521220       0.482053
# min       -44.807735      -2.836627     -10.295397      -2.604551
# 25%        -0.161703      -0.354453      -0.317485      -0.326763
# 50%        -0.011159       0.041016       0.016278      -0.052172
# 75%         0.147748       0.439738       0.350667       0.240261
# max        22.528412       4.584549       7.519589       3.517346
#
#                  V27            V28         Amount          Class
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean        0.001763       0.000547      88.472687       0.001667
# std         0.395744       0.328027     250.399437       0.040796
# min       -22.565679     -15.430084       0.000000       0.000000
# 25%        -0.070641      -0.052818       5.600000       0.000000
# 50%         0.001479       0.011288      22.000000       0.000000
# 75%         0.091208       0.078276      77.510000       0.000000
# max        31.612198      33.847808   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# All the features are normally distributed with a mean around 0 and std around 1 except the `Amount` column

# %%
X = df.iloc[:, 1:-1] # Not considering the Time feature
y = df['Class'].to_numpy()

# %% [markdown]
# ### Outliers

# %%
normal = X[y == 0]
fraud = X[y == 1]
normal.reset_index(drop=True, inplace=True)
fraud.reset_index(drop=True, inplace=True)
normal.shape, fraud.shape
# Out:
# ((283253, 29), (473, 29))

# %%
def plot_all_distributions(data:pd.DataFrame) -> None:
    fig, axes = plt.subplots(nrows=10, ncols=3, figsize=(10, 10))
    for col, ax in zip([i for i in range(0, 29)], axes.ravel()):
        ax.hist(data.iloc[:, col], bins=50, color="dodgerblue")
        ax.set_yticks([])
        ax.tick_params(which="major", axis="both", labelsize=5)
        ax.set_title(data.columns.values[col], fontsize=7)
    axes[9, 2].set_axis_off()
    fig.tight_layout()
    
plot_all_distributions(normal)

# %%
def detect_outliers(df:pd.DataFrame) -> tuple[pd.DataFrame, set]:
    data = []
    indexes = set()
    for col in df.columns.values:
        mean = df[col].mean()
        std = df[col].std()
        upper_bound = mean + 3*std
        lower_bound = mean - 3*std
        mask = ((df[col] > upper_bound) | (df[col] < lower_bound))
        items = df[mask].shape[0]
        indexes.update({idx for idx in df[mask].index.values})
        data.append([col, mean, std, upper_bound, lower_bound, items])

    outlier_report = pd.DataFrame(data, 
                                   columns=[
                                       "Column", "Mean", "Standard Deviation", 
                                       "Upper Bound", "Lower Bound", "Outliers"
                                   ])
    
    return outlier_report, indexes

# %%
outlier_report, indexes = detect_outliers(normal)
outlier_report.style.background_gradient(subset=[
    "Outliers"
])
# Out:
# <style type="text/css">
# #T_7c790_row0_col5 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_7c790_row1_col5 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_7c790_row2_col5 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_7c790_row3_col5 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_7c790_row4_col5 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_7c790_row5_col5 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_7c790_row6_col5 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_7c790_row7_col5 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_7c790_row8_col5, #T_7c790_row15_col5 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_7c790_row9_col5 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_7c790_row10_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_7c790_row11_col5 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_7c790_row12_col5 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_7c790_row13_col5 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_7c790_row14_col5 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_7c790_row16_col5 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_7c790_row17_col5 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_7c790_row18_col5 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_7c790_row19_col5 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_7c790_row20_col5 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_7c790_row21_col5 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_7c790_row22_col5 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_7c790_row23_col5 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_7c790_row24_col5 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_7c790_row25_col5 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_7c790_row26_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_7c790_row27_col5 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_7c790_row28_col5 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7c790_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Column</th>
#       <th class="col_heading level0 col1" >Mean</th>
#       <th class="col_heading level0 col2" >Standard Deviation</th>
#       <th class="col_heading level0 col3" >Upper Bound</th>
#       <th class="col_heading level0 col4" >Lower Bound</th>
#       <th class="col_heading level0 col5" >Outliers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c790_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c790_row0_col0" class="data row0 col0" >V1</td>
#       <td id="T_7c790_row0_col1" class="data row0 col1" >0.013439</td>
#       <td id="T_7c790_row0_col2" class="data row0 col2" >1.922179</td>
#       <td id="T_7c790_row0_col3" class="data row0 col3" >5.779975</td>
#       <td id="T_7c790_row0_col4" class="data row0 col4" >-5.753098</td>
#       <td id="T_7c790_row0_col5" class="data row0 col5" >3670</td>
#     </tr>
#     <tr>
#       <th id="T_7c790_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c790_row1_col0" class="data row1 col0" >V2</td>
#       <td id="T_7c790_row1_col1" class="data row1 col1" >-0.009829</td>
#       <td id="T_7c790_row1_col2" class="data row1 col2" >1.633520</td>
#       <td id="T_7c790_row1_col3" class="data row1 col3" >4.890731</td>
#       <td id="T_7c790_row1_col4" class="data row1 col4" >-4.910389</td>
#       <td id="T_7c790_row1_col5" class="data row1 col5" >4277</td>
#     </tr>
#     <tr>
#       <th id="T_7c790_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7c790_row2_col0" class="data row2 col0" >V3</td>
#       <td id="T_7c790_row2_col1" class="data row2 col1" >0.012853</td>
#       <td id="T_7c790_row2_col2" class="data row2 col2" >1.457593</td>
#       <td id="T_7c790_row2_col3" class="data row2 col3" >4.385632</td>
#       <td id="T_7c790_row2_col4" class="data row2 col4" >-4.359925</td>
#       <td id="T_7c790_row2_col5" class="data row2 col5" >1943</td>
#     </tr>
#     <tr>
#       <th id="T_7c790_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7c790_row3_col0" class="data row3 col0" >V4</td>
#       <td id="T_7c790_row3_col1" class="data row3 col1" >-0.010440</td>
#       <td id="T_7c790_row3_col2" class="data row3 col2" >1.398575</td>
#       <td id="T_7c790_row3_col3" class="data row3 col3" >4.185284</td>
#       <td id="T_7c790_row3_col4" class="data row3 col4" >-4.206164</td>
#       <td id="T_7c790_row3_col5" class="data row3 col5" >3124</td>
#     </tr>
#     <tr>
#       <th id="T_7c790_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7c790_row4_col0" class="data row4 col0" >V5</td>
#       <td id="T_7c790_row4_col1" class="data row4 col1" >0.006769</td>
#       <td id="T_7c790_row4_col2" class="data row4 col2" >1.355816</td>
#       <td id="T_7c790_row4_col3" class="data row4 col3" >4.074217</td>
#       <td id="T_7c790_row4_col4" class="data row4 col4" >-4.060680</td>
#       <td id="T_7c790_row4_col5" class="data row4 col5" >2906</td>
#     </tr>
#     <tr>
#       <th id="T_7c790_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7c790_row5_col0" class="data row5 col0" >V6</td>
#       <td id="T_7c790_row5_col1" class="data row5 col1" >0.001251</td>
#       <td id="T_7c790_row5_col2" class="data row5 col2" >1.329914</td>
#       <td id="T_7c790_row5_col3" class="data row5 col3" >3.990993</td>
#       <td id="T_7c790_row5_col4" class="data row5 col4" >-3.988491</td>
#       <td id="T_7c790_row5_col5" class="data row5 col5" >4624</td>
#     </tr>
#     <tr>
#       <th id="T_7c790_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7c790_row6_col0" class="data row6 col0" >V7</td>
#       <td id="T_7c790_row6_col1" class="data row6 col1" >0.010447</td>
#       <td id="T_7c790_row6_col2" class="data row6 col2" >1.177480</td>
#       <td id="T_7c790_row6_col3" class="data row6 col3" >3.542888</td>
#       <td id="T_7c790_row6_col4" class="data row6 col4" >-3.521994</td>
#       <td id="T_7c790_row6_col5" class="data row6 col5" >3513</td>
#     </tr>
#     <tr>
#       <th id="T_7c790_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7c790_row7_col0" class="data row7 col0" >V8</td>
#       <td id="T_7c790_row7_col1" class="data row7 col1" >-0.002448</td>
#       <td id="T_7c790_row7_col2" class="data row7 col2" >1.157140</td>
#       <td id="T_7c790_row7_col3" class="data row7 col3" >3.468972</td>
#       <td id="T_7c790_row7_col4" class="data row7 col4" >-3.473868</td>
#       <td id="T_7c790_row7_col5" class="data row7 col5" >4190</td>
#     </tr>
#     <tr>
#       <th id="T_7c790_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7c790_row8_col0" class="data row8 col0" >V9</td>
#       <td id="T_7c790_row8_col1" class="data row8 col1" >0.002613</td>
#       <td id="T_7c790_row8_col2" class="data row8 col2" >1.086902</td>
#       <td id="T_7c790_row8_col3" class="data row8 col3" >3.263318</td>
#       <td id="T_7c790_row8_col4" class="data row8 col4" >-3.258093</td>
#       <td id="T_7c790_row8_col5" class="data row8 col5" >2177</td>
#     </tr>
#     <tr>
#       <th id="T_7c790_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7c790_row9_col0" class="data row9 col0" >V10</td>
#       <td id="T_7c790_row9_col1" class="data row9 col1" >0.007663</td>
#       <td id="T_7c790_row9_col2" class="data row9 col2" >1.036321</td>
#       <td id="T_7c790_row9_col3" class="data row9 col3" >3.116625</td>
#       <td id="T_7c790_row9_col4" class="data row9 col4" >-3.101299</td>
#       <td id="T_7c790_row9_col5" class="data row9 col5" >3333</td>
#     </tr>
#     <tr>
#       <th id="T_7c790_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7c790_row10_col0" class="data row10 col0" >V11</td>
#       <td id="T_7c790_row10_col1" class="data row10 col1" >-0.006004</td>
#       <td id="T_7c790_row10_col2" class="data row10 col2" >1.002257</td>
#       <td id="T_7c790_row10_col3" class="data row10 col3" >3.000769</td>
#       <td i

# %%
ax = outlier_report.sort_values(by="Outliers").plot(
    kind="barh", x="Column", y="Outliers",
    color="indianred"
)

ax.tick_params(which="major", axis="both", labelsize=7)
ax.set_ylabel("Features")
ax.set_xlabel("Outlier Count")
ax.text(3000, 4, f"Total Number of outliers {len(indexes)}", fontsize=9, color="r")
ax.set_title("Outliers Detected using Z-score method")
ax.get_legend().remove()

# %%
clean_normal_X = normal.drop(indexes)
clean_normal_X.reset_index(drop=True, inplace=True)
clean_normal_X.shape
# Out:
# (243221, 29)

# %%
plot_all_distributions(clean_normal_X)

# %%
plot_all_distributions(fraud)

# %%
outlier_report, indexes = detect_outliers(fraud)
outlier_report.style.background_gradient(subset=[
    "Outliers"
])
# Out:
# <style type="text/css">
# #T_63e5c_row0_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_63e5c_row1_col5 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_63e5c_row2_col5, #T_63e5c_row4_col5 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_63e5c_row3_col5, #T_63e5c_row11_col5, #T_63e5c_row12_col5, #T_63e5c_row13_col5, #T_63e5c_row15_col5, #T_63e5c_row16_col5, #T_63e5c_row17_col5, #T_63e5c_row18_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_63e5c_row5_col5, #T_63e5c_row27_col5 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_63e5c_row6_col5, #T_63e5c_row22_col5 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_63e5c_row7_col5, #T_63e5c_row28_col5 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_63e5c_row8_col5 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_63e5c_row9_col5, #T_63e5c_row19_col5, #T_63e5c_row21_col5 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_63e5c_row10_col5 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_63e5c_row14_col5, #T_63e5c_row23_col5, #T_63e5c_row25_col5 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_63e5c_row20_col5, #T_63e5c_row26_col5 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_63e5c_row24_col5 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# </style>
# <table id="T_63e5c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Column</th>
#       <th class="col_heading level0 col1" >Mean</th>
#       <th class="col_heading level0 col2" >Standard Deviation</th>
#       <th class="col_heading level0 col3" >Upper Bound</th>
#       <th class="col_heading level0 col4" >Lower Bound</th>
#       <th class="col_heading level0 col5" >Outliers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63e5c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63e5c_row0_col0" class="data row0 col0" >V1</td>
#       <td id="T_63e5c_row0_col1" class="data row0 col1" >-4.498280</td>
#       <td id="T_63e5c_row0_col2" class="data row0 col2" >6.593145</td>
#       <td id="T_63e5c_row0_col3" class="data row0 col3" >15.281156</td>
#       <td id="T_63e5c_row0_col4" class="data row0 col4" >-24.277716</td>
#       <td id="T_63e5c_row0_col5" class="data row0 col5" >13</td>
#     </tr>
#     <tr>
#       <th id="T_63e5c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_63e5c_row1_col0" class="data row1 col0" >V2</td>
#       <td id="T_63e5c_row1_col1" class="data row1 col1" >3.405965</td>
#       <td id="T_63e5c_row1_col2" class="data row1 col2" >4.122500</td>
#       <td id="T_63e5c_row1_col3" class="data row1 col3" >15.773465</td>
#       <td id="T_63e5c_row1_col4" class="data row1 col4" >-8.961536</td>
#       <td id="T_63e5c_row1_col5" class="data row1 col5" >9</td>
#     </tr>
#     <tr>
#       <th id="T_63e5c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_63e5c_row2_col0" class="data row2 col0" >V3</td>
#       <td id="T_63e5c_row2_col1" class="data row2 col1" >-6.729599</td>
#       <td id="T_63e5c_row2_col2" class="data row2 col2" >6.909647</td>
#       <td id="T_63e5c_row2_col3" class="data row2 col3" >13.999343</td>
#       <td id="T_63e5c_row2_col4" class="data row2 col4" >-27.458541</td>
#       <td id="T_63e5c_row2_col5" class="data row2 col5" >8</td>
#     </tr>
#     <tr>
#       <th id="T_63e5c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_63e5c_row3_col0" class="data row3 col0" >V4</td>
#       <td id="T_63e5c_row3_col1" class="data row3 col1" >4.472591</td>
#       <td id="T_63e5c_row3_col2" class="data row3 col2" >2.871523</td>
#       <td id="T_63e5c_row3_col3" class="data row3 col3" >13.087159</td>
#       <td id="T_63e5c_row3_col4" class="data row3 col4" >-4.141977</td>
#       <td id="T_63e5c_row3_col5" class="data row3 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_63e5c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_63e5c_row4_col0" class="data row4 col0" >V5</td>
#       <td id="T_63e5c_row4_col1" class="data row4 col1" >-2.957197</td>
#       <td id="T_63e5c_row4_col2" class="data row4 col2" >5.278831</td>
#       <td id="T_63e5c_row4_col3" class="data row4 col3" >12.879297</td>
#       <td id="T_63e5c_row4_col4" class="data row4 col4" >-18.793690</td>
#       <td id="T_63e5c_row4_col5" class="data row4 col5" >8</td>
#     </tr>
#     <tr>
#       <th id="T_63e5c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_63e5c_row5_col0" class="data row5 col0" >V6</td>
#       <td id="T_63e5c_row5_col1" class="data row5 col1" >-1.432518</td>
#       <td id="T_63e5c_row5_col2" class="data row5 col2" >1.715347</td>
#       <td id="T_63e5c_row5_col3" class="data row5 col3" >3.713524</td>
#       <td id="T_63e5c_row5_col4" class="data row5 col4" >-6.578560</td>
#       <td id="T_63e5c_row5_col5" class="data row5 col5" >5</td>
#     </tr>
#     <tr>
#       <th id="T_63e5c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_63e5c_row6_col0" class="data row6 col0" >V7</td>
#       <td id="T_63e5c_row6_col1" class="data row6 col1" >-5.175912</td>
#       <td id="T_63e5c_row6_col2" class="data row6 col2" >6.858024</td>
#       <td id="T_63e5c_row6_col3" class="data row6 col3" >15.398160</td>
#       <td id="T_63e5c_row6_col4" class="data row6 col4" >-25.749984</td>
#       <td id="T_63e5c_row6_col5" class="data row6 col5" >7</td>
#     </tr>
#     <tr>
#       <th id="T_63e5c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_63e5c_row7_col0" class="data row7 col0" >V8</td>
#       <td id="T_63e5c_row7_col1" class="data row7 col1" >0.953255</td>
#       <td id="T_63e5c_row7_col2" class="data row7 col2" >5.585950</td>
#       <td id="T_63e5c_row7_col3" class="data row7 col3" >17.711103</td>
#       <td id="T_63e5c_row7_col4" class="data row7 col4" >-15.804594</td>
#       <td id="T_63e5c_row7_col5" class="data row7 col5" >11</td>
#     </tr>
#     <tr>
#       <th id="T_63e5c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_63e5c_row8_col0" class="data row8 col0" >V9</td>
#       <td id="T_63e5c_row8_col1" class="data row8 col1" >-2.522124</td>
#       <td id="T_63e5c_row8_col2" class="data row8 col2" >2.465047</td>
#       <td id="T_63e5c_row8_col3" class="data row8 col3" >4.873016</td>
#       <td id="T_63e5c_row8_col4" class="data row8 col4" >-9.917264</td>
#       <td id="T_63e5c_row8_col5" class="data row8 col5" >4</td>
#     </tr>
#     <tr>
#       <th id="T_63e5c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_63e5c_row9_col0" class="data row9 col0" >V10</td>
#       <td id="T_63e5c_row9_col1" class="data row9 col1" >-5.453274</td>
#       <td id="T_63e5c_row9_col2" class="data row9 col2" >4.706451</td>
#       <td id="T_63e5c_row9_col3" class="data row9 col3" >8.666079</td>
#       <td id="T_63e5c_row9_col4" class="data row9 col4" >-19.572627</td>
#       <td id="T_63e5c_row9_col5" class="data row9 col5" >6</td>
#     </tr>
#     <tr>
#       <th id="T_63e5c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_63e5c_row10_col0" class="data row10 col0" >V11</td>
#       <td id="T_63e5c_row10_col1" class="data row10 col1" >3.716347</td>
#       <td id="T_63e5c_row10_col2" class="data row10 col2" >2.672817</td>
#       <td id="T_63e5c_row10_col3" class="data row10 col3" >11.734799</td>
#       <td id="T_63e5c_row10_col4" class="data row10 col4" >-4.302106</td>
#       <td id="T_63e5c_row10_col5" class="data row10 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_63e5c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_63e5c_row11_col0" class="data row11 col0" >V12</td>
#       <td id="T_63e5c_row11_col1" class="data row11 col1" >-6.103254</td>
#       <td id="T_63e5c_row11_col2" class="data row11 col2" >4.582331</td>
#       <td id="T_63e5c_row11_col3" class="data row11 col3" >7.643738</td>
#       <td id="T_63e5c_row11_col4" class="data row11 col4" >-19.850246</td>
#       <td id="T_63e5c_row11_col5" class="data row11 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_63e5c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td

# %%
clean_fraud_X = fraud.drop(indexes)
clean_fraud_X.reset_index(drop=True, inplace=True)
clean_fraud_X.shape
# Out:
# (425, 29)

# %%
plot_all_distributions(clean_fraud_X)

# %%
sample_idx = np.random.randint(0, clean_normal_X.shape[0], size=500)

# %%
normal_X = clean_normal_X.drop(sample_idx, axis=0)
normal_y = np.zeros(clean_normal_X.shape[0])
mixed_X = pd.concat([clean_normal_X.iloc[sample_idx], clean_fraud_X])
mixed_y = np.concatenate((np.zeros(500), np.ones(clean_fraud_X.shape[0])), axis=0)

# %% [markdown]
# Here I have randomly sampled 500 normal data points, so that it can be visualized properly for analysis

# %%
normal_X.reset_index(drop=True, inplace=True)
mixed_X.reset_index(drop=True, inplace=True)

# %%
print("normal_X.shape = ", normal_X.shape)
print("mixed_X.shape  = ", mixed_X.shape)
# Out:
# normal_X.shape =  (242721, 29)
# mixed_X.shape  =  (925, 29)

# %%
mean_amount = normal_X["Amount"].mean()
std_amount = normal_X["Amount"].std()

normal_X["Amount"] = normal_X["Amount"].apply(lambda x: np.round((x-mean_amount)/std_amount, 6))
mixed_X["Amount"] = mixed_X["Amount"].apply(
    lambda x: np.round((x-mean_amount)/std_amount, 6)
)

# %% [markdown]
# ## EDA and Feature Extraction

# %%
palette = sns.color_palette('summer')
plt.pie(df['Class'].value_counts().to_list(), labels=["Normal", "Fraud"], colors=palette, autopct="%.2f%%")
plt.show()

# %%
sns.heatmap(normal_X.corr(), cmap="Purples")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Features for normal data are uncorrelated

# %%
sns.heatmap(fraud.corr(), cmap="Purples")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Whereas for fraud data some features are correleated

# %% [markdown]
# Since the mixed set contains both type of samples, further analysis is performed on it.

# %%
mixed_X["Target"] = mixed_y
sns.set_style("ticks")
ax = mixed_X.corr().iloc[:-1, -1].plot(kind="barh", color="dodgerblue", figsize=(7,7), width=1)
ax.tick_params(which="major", axis="both", labelsize=7)
ax.axvline(0, color="gray")
ax.axvline(-0.7, linestyle="--", color="gray")
ax.axvline(0.7, linestyle="--", color="gray")
ax.set_xlabel("Correlation Coefficient")
ax.set_title("Correlation with target feature", fontsize=12)
mixed_X.drop(["Target"], axis=1, inplace=True)

# %%
pca = PCA(n_components=2)
data = pca.fit_transform(mixed_X)
sns.set_style("whitegrid")
plt.plot(data[:, 0][mixed_y==0], data[:, 1][mixed_y==0],"o", markersize=2, c="g", label="Normal")
plt.plot(data[:, 0][mixed_y==1], data[:, 1][mixed_y==1],"o", markersize=2, c="orange", label="Anomaly")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("Principal Component = 2")
plt.legend()

# %% [markdown]
# Using 2 principal components the distinction between the fraud and normal data is visible

# %%
pca = PCA(n_components=3)
data = pca.fit_transform(mixed_X)

good = data[mixed_y == 0]
bad = data[mixed_y == 1]

fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(projection ='3d')
ax.plot3D(good[:, 0], good[:, 1], good[:, 2], "o", markersize=2, c="g", label="Normal")
ax.plot3D(bad[:, 0], bad[:, 1], bad[:, 2], "o", markersize=2, c="orange", label="Anomaly")
ax.set_xlabel("PC1")
ax.set_ylabel("PC2")
ax.set_zlabel("PC3")
ax.set_title("Principal Components = 3")

ax.legend()
plt.show()

# %% [markdown]
# Here also using 3 principal components it can be observed that the fraud data is spread across the space whereas the normal data is centered around 0

# %%
lda = LinearDiscriminantAnalysis(n_components=1)
data = lda.fit_transform(mixed_X, mixed_y)

plt.plot(data[mixed_y==0], "o", markersize=2, c="dodgerblue", label="Normal")
plt.plot(data[mixed_y==1], "o", markersize=2, c="darkorange", label="Anomaly")
plt.legend()
plt.xlabel("Index")
plt.ylabel("Transformed X")
plt.title("LDA component = 1")
plt.show()

# %% [markdown]
# Here also LDA using 1 component separates the data well

# %% [markdown]
# ## ML models

# %%
sample_X = pd.concat([clean_normal_X.iloc[sample_idx], clean_fraud_X])
sample_y = np.concatenate((np.zeros(500), np.ones(clean_fraud_X.shape[0])), axis=0)
sample_X.reset_index(drop=True, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    sample_X, sample_y, stratify=sample_y, test_size=0.1, random_state=42
)

# %%
print("X_train.shape = ", X_train.shape)
print("y_train.shape = ", y_train.shape)
print("X_test.shape = ", X_test.shape)
print("y_test.shape = ", y_test.shape)
# Out:
# X_train.shape =  (832, 29)
# y_train.shape =  (832,)
# X_test.shape =  (93, 29)
# y_test.shape =  (93,)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
def train_models(train_X:np.ndarray, train_y:np.ndarray, test_X:np.ndarray, test_y:np.ndarray) -> tuple[list, pd.DataFrame]:
    models = [
        LogisticRegression(),
        DecisionTreeClassifier(),
        BernoulliNB(),
        RandomForestClassifier(),
        GradientBoostingClassifier()
    ]
    scores = {
        "precision":[],
        "recall":[],
        "f1":[]
    }
    for model in models:
        model.fit(train_X, train_y)
        y_pred = model.predict(test_X)
        scores["precision"].append(precision_score(test_y, y_pred))
        scores["recall"].append(recall_score(test_y, y_pred))
        scores["f1"].append(f1_score(test_y, y_pred))
    model_report = pd.DataFrame(zip(
        [model.__class__.__name__ for model in models],
        scores["precision"], scores["recall"], scores["f1"]
    ))
    model_report.columns = ["Model", "Precision", "Recall", "F1 Score"]
    return models, model_report

# %% [markdown]
# ### Using original data

# %%
models, report = train_models(X_train, y_train, X_test, y_test)
report.style.background_gradient(subset=["Precision", "Recall", "F1 Score"], axis=0)
# Out:
# <style type="text/css">
# #T_82c6e_row0_col1 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_82c6e_row0_col2 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_82c6e_row0_col3 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_82c6e_row1_col1, #T_82c6e_row2_col2, #T_82c6e_row2_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_82c6e_row1_col2, #T_82c6e_row2_col1, #T_82c6e_row3_col2, #T_82c6e_row3_col3, #T_82c6e_row4_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_82c6e_row1_col3 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_82c6e_row3_col1 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_82c6e_row4_col1 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_82c6e_row4_col3 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_82c6e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Precision</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >F1 Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82c6e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_82c6e_row0_col0" class="data row0 col0" >LogisticRegression</td>
#       <td id="T_82c6e_row0_col1" class="data row0 col1" >0.951220</td>
#       <td id="T_82c6e_row0_col2" class="data row0 col2" >0.906977</td>
#       <td id="T_82c6e_row0_col3" class="data row0 col3" >0.928571</td>
#     </tr>
#     <tr>
#       <th id="T_82c6e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_82c6e_row1_col0" class="data row1 col0" >DecisionTreeClassifier</td>
#       <td id="T_82c6e_row1_col1" class="data row1 col1" >0.909091</td>
#       <td id="T_82c6e_row1_col2" class="data row1 col2" >0.930233</td>
#       <td id="T_82c6e_row1_col3" class="data row1 col3" >0.919540</td>
#     </tr>
#     <tr>
#       <th id="T_82c6e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_82c6e_row2_col0" class="data row2 col0" >BernoulliNB</td>
#       <td id="T_82c6e_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_82c6e_row2_col2" class="data row2 col2" >0.790698</td>
#       <td id="T_82c6e_row2_col3" class="data row2 col3" >0.883117</td>
#     </tr>
#     <tr>
#       <th id="T_82c6e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_82c6e_row3_col0" class="data row3 col0" >RandomForestClassifier</td>
#       <td id="T_82c6e_row3_col1" class="data row3 col1" >0.975610</td>
#       <td id="T_82c6e_row3_col2" class="data row3 col2" >0.930233</td>
#       <td id="T_82c6e_row3_col3" class="data row3 col3" >0.952381</td>
#     </tr>
#     <tr>
#       <th id="T_82c6e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_82c6e_row4_col0" class="data row4 col0" >GradientBoostingClassifier</td>
#       <td id="T_82c6e_row4_col1" class="data row4 col1" >0.930233</td>
#       <td id="T_82c6e_row4_col2" class="data row4 col2" >0.930233</td>
#       <td id="T_82c6e_row4_col3" class="data row4 col3" >0.930233</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Using PCA

# %%
pca = PCA(n_components=2)
X_train_p = pca.fit_transform(X_train)
X_test_p = pca.transform(X_test)

# %%
models, report = train_models(X_train_p, y_train, X_test_p, y_test)
report.style.background_gradient(subset=["Precision", "Recall", "F1 Score"], axis=0)
# Out:
# <style type="text/css">
# #T_bee1a_row0_col1, #T_bee1a_row2_col1, #T_bee1a_row3_col2, #T_bee1a_row4_col2, #T_bee1a_row4_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_bee1a_row0_col2 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_bee1a_row0_col3 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_bee1a_row1_col1, #T_bee1a_row1_col3, #T_bee1a_row2_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_bee1a_row1_col2 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_bee1a_row2_col3 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_bee1a_row3_col1 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_bee1a_row3_col3 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_bee1a_row4_col1 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bee1a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Precision</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >F1 Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bee1a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bee1a_row0_col0" class="data row0 col0" >LogisticRegression</td>
#       <td id="T_bee1a_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_bee1a_row0_col2" class="data row0 col2" >0.767442</td>
#       <td id="T_bee1a_row0_col3" class="data row0 col3" >0.868421</td>
#     </tr>
#     <tr>
#       <th id="T_bee1a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bee1a_row1_col0" class="data row1 col0" >DecisionTreeClassifier</td>
#       <td id="T_bee1a_row1_col1" class="data row1 col1" >0.840909</td>
#       <td id="T_bee1a_row1_col2" class="data row1 col2" >0.860465</td>
#       <td id="T_bee1a_row1_col3" class="data row1 col3" >0.850575</td>
#     </tr>
#     <tr>
#       <th id="T_bee1a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bee1a_row2_col0" class="data row2 col0" >BernoulliNB</td>
#       <td id="T_bee1a_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_bee1a_row2_col2" class="data row2 col2" >0.744186</td>
#       <td id="T_bee1a_row2_col3" class="data row2 col3" >0.853333</td>
#     </tr>
#     <tr>
#       <th id="T_bee1a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bee1a_row3_col0" class="data row3 col0" >RandomForestClassifier</td>
#       <td id="T_bee1a_row3_col1" class="data row3 col1" >0.926829</td>
#       <td id="T_bee1a_row3_col2" class="data row3 col2" >0.883721</td>
#       <td id="T_bee1a_row3_col3" class="data row3 col3" >0.904762</td>
#     </tr>
#     <tr>
#       <th id="T_bee1a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bee1a_row4_col0" class="data row4 col0" >GradientBoostingClassifier</td>
#       <td id="T_bee1a_row4_col1" class="data row4 col1" >0.974359</td>
#       <td id="T_bee1a_row4_col2" class="data row4 col2" >0.883721</td>
#       <td id="T_bee1a_row4_col3" class="data row4 col3" >0.926829</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Using LDA

# %%
lda = LinearDiscriminantAnalysis(n_components=1)
X_train_l = lda.fit_transform(X_train, y_train)
X_test_l = lda.transform(X_test)

# %%
models, report = train_models(X_train_l, y_train, X_test_l, y_test)
report.style.background_gradient(subset=["Precision", "Recall", "F1 Score"], axis=0)
# Out:
# <style type="text/css">
# #T_e8e31_row0_col1, #T_e8e31_row0_col3, #T_e8e31_row2_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e8e31_row0_col2 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_e8e31_row1_col1, #T_e8e31_row3_col1 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_e8e31_row1_col2, #T_e8e31_row3_col2, #T_e8e31_row4_col1, #T_e8e31_row4_col2, #T_e8e31_row4_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e8e31_row1_col3, #T_e8e31_row3_col3 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_e8e31_row2_col1 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_e8e31_row2_col3 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# </style>
# <table id="T_e8e31_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Precision</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >F1 Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8e31_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8e31_row0_col0" class="data row0 col0" >LogisticRegression</td>
#       <td id="T_e8e31_row0_col1" class="data row0 col1" >0.880952</td>
#       <td id="T_e8e31_row0_col2" class="data row0 col2" >0.860465</td>
#       <td id="T_e8e31_row0_col3" class="data row0 col3" >0.870588</td>
#     </tr>
#     <tr>
#       <th id="T_e8e31_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8e31_row1_col0" class="data row1 col0" >DecisionTreeClassifier</td>
#       <td id="T_e8e31_row1_col1" class="data row1 col1" >0.904762</td>
#       <td id="T_e8e31_row1_col2" class="data row1 col2" >0.883721</td>
#       <td id="T_e8e31_row1_col3" class="data row1 col3" >0.894118</td>
#     </tr>
#     <tr>
#       <th id="T_e8e31_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e8e31_row2_col0" class="data row2 col0" >BernoulliNB</td>
#       <td id="T_e8e31_row2_col1" class="data row2 col1" >0.923077</td>
#       <td id="T_e8e31_row2_col2" class="data row2 col2" >0.837209</td>
#       <td id="T_e8e31_row2_col3" class="data row2 col3" >0.878049</td>
#     </tr>
#     <tr>
#       <th id="T_e8e31_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e8e31_row3_col0" class="data row3 col0" >RandomForestClassifier</td>
#       <td id="T_e8e31_row3_col1" class="data row3 col1" >0.904762</td>
#       <td id="T_e8e31_row3_col2" class="data row3 col2" >0.883721</td>
#       <td id="T_e8e31_row3_col3" class="data row3 col3" >0.894118</td>
#     </tr>
#     <tr>
#       <th id="T_e8e31_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e8e31_row4_col0" class="data row4 col0" >GradientBoostingClassifier</td>
#       <td id="T_e8e31_row4_col1" class="data row4 col1" >0.950000</td>
#       <td id="T_e8e31_row4_col2" class="data row4 col2" >0.883721</td>
#       <td id="T_e8e31_row4_col3" class="data row4 col3" >0.915663</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## AutoEncoder

# %% [markdown]
# - An AutoEncoder model is trained to model the normal data. Given a normal data sample, the model reconstructs a similar sample.
# - The reconstruction loss given a normal sample will be less than when a fraud sample is passed to the model.
#
# - Using the reconstruction loss the fraud and normal data can be identified.

# %%
config = {
    "input_shape":normal_X.shape,
    "batch_size":64,
    "epochs":50,
    "learning_rate":0.001,
}

# %%
model = tf.keras.Sequential(
    [
        tf.keras.Input(shape=(config["input_shape"][1],)),
        layers.Dense(32, activation='relu'),
        layers.Dense(16, activation='relu'),
        layers.Dense(8, activation='relu'),
        layers.Dense(16, activation='relu'),
        layers.Dense(config["input_shape"][1], activation='linear')
    ]
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                960
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                144
# _________________________________________________________________
# dense_4 (Dense)              (None, 29)                493
# =================================================================
# Total params: 2,261
# Trainable params: 2,261
# Non-trainable params: 0
# _________________________________________________________________
# 2025-01-17 11:59:56.104081: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-01-17 11:59:56.112740: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-01-17 11:59:56.113042: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-01-17 11:59:56.114430: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-17 11:59:56.114749: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-01-17 11:59:56.115021: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-01-17 11:59:56.115242: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-01-17 11:59:56.455378: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-01-17 11:59:56.455699: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-01-17 11:59:56.455894: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-01-17 11:59:56.456058: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 427 MB memory:  -> device: 0, name: NVIDIA GeForce GT 710, pci bus id: 0000:01:00.0, compute capability: 3.5

# %%
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=config["learning_rate"]))

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath='best_model.keras',
    monitor='loss',
    mode='min',
    save_best_only=True,
    save_weights_only=False,
    verbose=1
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

callbacks = [checkpoint, early_stopping]

# %%
history = model.fit(
    normal_X, normal_X,
    epochs=config['epochs'],
    batch_size=config['batch_size'],
    callbacks=callbacks
)
# Out:
# 2025-01-17 11:59:56.764124: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 3793/3793 [==============================] - 7s 2ms/step - loss: 0.2393
#
# Epoch 00001: loss improved from inf to 0.23934, saving model to best_model.keras
# Epoch 2/50
# 3793/3793 [==============================] - 7s 2ms/step - loss: 0.1748
#
# Epoch 00002: loss improved from 0.23934 to 0.17480, saving model to best_model.keras
# Epoch 3/50
# 3793/3793 [==============================] - 7s 2ms/step - loss: 0.1689
#
# Epoch 00003: loss improved from 0.17480 to 0.16888, saving model to best_model.keras
# Epoch 4/50
# 3793/3793 [==============================] - 6s 2ms/step - loss: 0.1620
#
# Epoch 00004: loss improved from 0.16888 to 0.16198, saving model to best_model.keras
# Epoch 5/50
# 3793/3793 [==============================] - 7s 2ms/step - loss: 0.1574
#
# Epoch 00005: loss improved from 0.16198 to 0.15740, saving model to best_model.keras
# Epoch 6/50
# 3793/3793 [==============================] - 5s 1ms/step - loss: 0.1548
#
# Epoch 00006: loss improved from 0.15740 to 0.15484, saving model to best_model.keras
# Epoch 7/50
# 3793/3793 [==============================] - 6s 2ms/step - loss: 0.1532
#
# Epoch 00007: loss improved from 0.15484 to 0.15318, saving model to best_model.keras
# Epoch 8/50
# 3793/3793 [==============================] - 7s 2ms/step - loss: 0.1518
#
# Epoch 00008: loss improved from 0.15318 to 0.15179, saving model to best_model.keras
# Epoch 9/50
# 3793/3793 [==============================] - 5s 1ms/step - loss: 0.1505
#
# Epoch 00009: loss improved from 0.15179 to 0.15053, saving model to best_model.keras
# Epoch 10/50
# 3793/3793 [==============================] - 5s 1ms/step - loss: 0.1496
#
# Epoch 00010: loss improved from 0.15053 to 0.14956, saving model to best_model.keras
# Epoch 11/50
# 3793/3793 [==============================] - 5s 1ms/step - loss: 0.1487
#
# Epoch 00011: loss improved from 0.14956 to 0.14871, saving model to best_model.keras
# Epoch 12/50
# 3793/3793 [==============================] - 6s 2ms/step - loss: 0.1481
#
# Epoch 00012: loss improved from 0.14871 to 0.14806, saving model to best_model.keras
# Epoch 13/50
# 3793/3793 [==============================] - 6s 2ms/step - loss: 0.1476
#
# Epoch 00013: loss improved from 0.14806 to 0.14762, saving model to best_model.keras
# Epoch 14/50
# 3793/3793 [==============================] - 7s 2ms/step - loss: 0.1470
#
# Epoch 00014: loss improved from 0.14762 to 0.14703, saving model to best_model.keras
# Epoch 15/50
# 3793/3793 [==============================] - 5s 1ms/step - loss: 0.1441
#
# Epoch 00015: loss improved from 0.14703 to 0.14407, saving model to best_model.keras
# Epoch 16/50
# 3793/3793 [==============================] - 5s 1ms/step - loss: 0.1427
#
# Epoch 00016: loss improved from 0.14407 to 0.14273, saving model to best_model.keras
# Epoch 17/50
# 3793/3793 [==============================] - 5s 1ms/step - loss: 0.1415
#
# Epoch 00017: loss improved from 0.14273 to 0.14152, saving model to best_model.keras
# Epoch 18/50
# 3793/3793 [==============================] - 5s 1ms/step - loss: 0.1398
#
# Epoch 00018: loss improved from 0.14152 to 0.13985, saving model to best_model.keras
# Epoch 19/50
# 3793/3793 [==============================] - 5s 1ms/step - loss: 0.1377
#
# Epoch 00019: loss improved from 0.13985 to 0.13773, saving model to best_model.keras
# Epoch 20/50
# 3793/3793 [==============================] - 5s 1ms/step - loss: 0.1359
#
# Epoch 00020: loss improved from 0.13773 to 0.13587, saving model to best_model.keras
# Epoch 21/50
# 3793/3793 [==============================] - 7s 2ms/step - loss: 0.1346
#
# Epoch 00021: loss improved from 0.13587 to 0.13463, saving model to best_model.keras
# Epoch 22/50
# 3793/3793 [==============================] - 6s 2ms/step - loss: 0.1336
#
# Epoch 00022: loss improved from 0.13463 to 0.13362, saving model to best_model.keras
# Epoch 23/50
# 3793/3793 [==============================] - 6s 2ms/step - loss: 0.1329
#
# Epoch 00023: loss improved from 0.13362 to 0.13287, saving model to best_model.keras
# Epoch 24/50
# 3793/3793 [==============================] - 6s 2ms/step - loss: 0.1323
#
# Epoch 00024: loss improved from 0.13287 to 0.13226, saving model to best_model.keras
# Epoch 25/50
# 3793/3793 [==============================] - 6s 2ms/step - loss: 0.1318
#
# Epoch 00025: loss improved from 0.13226 to 0.13185, saving model to best_model.keras
# Epoch 26/50
# 3793/3793 [==============================] - 6s 2ms/step - loss: 0.1315
#
# Epoch 00026: loss improved from 0.13185 to 0.13153, saving model to best_model.keras
# Epoch 27/50
# 3793/3793 [==============================] - 8s 2ms/step - loss: 0.1314
#
# Epoch 00027: loss improved from 0.13153 to 0.13137, saving model to best_model.keras
# Epoch 28/50
# 3793/3793 [==============================] - 7s 2ms/step - loss: 0.1312
#
# Epoch 00028: loss improved from 0.13137 to 0.13116, saving model to best_model.keras
# Epoch 29/50
# 3793/3793 [==============================] - 7s 2ms/step - loss: 0.1310
#
# Epoch 00029: loss improved from 0.13116 to 0.13098, saving model to best_model.keras
# Epoch 30/50
# 3793/3793 [==============================] - 7s 2ms/step - loss: 0.1309
#
# Epoch 00030: loss improved from 0.13098 to 0.13086, saving model to best_model.keras
# Epoch 31/50
# 3793/3793 [==============================] - 6s 2ms/step - loss: 0.1307
#
# Epoch 00031: loss improved from 0.13086 to 0.13071, saving model to best_model.keras
# Epoch 32/50
# 3793/3793 [==============================] - 6s 1ms/step - loss: 0.1306
#
# Epoch 00032: loss improved from 0.13071 to 0.13064, saving model to best_model.keras
# Epoch 33/50
# 3793/3793 [==============================] - 6s 2ms/step - loss: 0.1306
#
# Epoch 00033: loss improved from 0.13064 to 0.13058, saving model to best_model.keras
# Epoch 34/50
# 3793/3793 [==============================] - 6s 1ms/step - loss: 0.1305
#
# Epoch 00034: loss improved from 0.13058 to 0.13052, saving model to best_model.keras
# Epoch 35/50
# 3793/3793 [==============================] - 6s 2ms/step - loss: 0.1304
#
# Epoch 00035: loss improved from 0.13052 to 0.13043, saving model to best_model.keras
# Epoch 36/50
# 3793/3793 [==============================] - 6s 2ms/step - loss: 0.1304
#
# Epoch 00036: loss did not improve from 0.13043
# Epoch 37/50
# 3793/3793 [==============================] - 6s 2ms/step - loss: 0.1303
#
# Epoch 00037: loss improved from 0.13043 to 0.13034, saving model to best_model.keras
# Epoch 38/50
# 3793/3793 [==============================] - 7s 2ms/step - loss: 0.1303
#
# Epoch 00038: loss improved from 0.13034 to 0.13032, saving model to best_model.keras
# Epoch 39/50
# 3793/3793 [==============================] - 6s 2ms/step - loss: 0.1302
#
# Epoch 00039: loss improved from 0.13032 to 0.13017, saving model to best_model.keras
# Epoch 40/50
# 3793/3793 [==============================] - 5s 1ms/step - loss: 0.1300
#
# Epoch 00040: loss improved from 0.13017 to 0.13005, saving model to best_model.keras
# Epoch 41/50
# 3793/3793 [==============================] - 6s 2ms/step - loss: 0.1298
#
# Epoch 00041: loss improved from 0.13005 to 0.12979, saving model to best_model.keras
# Epoch 42/50
# 3793/3793 [==============================] - 5s 1ms/step - loss: 0.1293
#
# Epoch 00042: loss improved from 0.12979 to 0.12930, saving model to best_model.keras
# Epoch 43/50
# 3793/3793 [==============================] - 5s 1ms/step - loss: 0.1288
#
# Epoch 00043: loss improved from 0.12930 to 0.12875, saving model to best_model.keras
# Epoch 44/50
# 3793/3793 [==============================] - 5s 1ms/step - loss: 0.1278
#
# Epoch 00044: loss improved from 0.12875 to 0.12779, saving model to best_model.keras
# Epoch 45/50
# 3793/3793 [==============================] - 5s 1ms/step - loss: 0.1248
#
# Epoch 00045: loss improved from 0.12779 to 0.12484, saving model to best_model.keras
# Epoch 46/50
# 3793/3793 [==============================] - 5s 1ms/step - loss: 0.1223
#
# Epoch 00046: loss improved from 0.12484 to 0.12225, saving model to best_model.keras
# Epoch 47/50
# 3793/3793 [==============================] - 6s 1ms/step - loss: 0.1213
#
# Epoch 00047: loss improved from 0.12225 to 0.12135, saving model to best_model.keras
# Epoch 48/50
# 3793/3793 [==============================] - 5s 1ms/step - loss: 0.1209
#
# Epoch 00048: loss improved from 0.12135 to 0.12089, saving model to best_model.keras
# Epoch 49/50
# 3793/3793 [==============================] - 5s 1ms/step - loss: 0.1207
# Epoch 00049: loss improved from 0.12089 to 0.12066, saving model to best_model.keras
# Epoch 50/50
# 3793/3793 [==============================] - 5s 1ms/step - loss: 0.1204
#
# Epoch 00050: loss improved from 0.12066 to 0.12040, saving model to best_model.keras

# %% [markdown]
# ## Evaluation

# %%
plt.plot(history.history['loss'], c='r')
plt.title("Loss over epochs")
plt.xlabel("Epochs")
plt.ylabel("MSE")
plt.show()

# %%
pred = model.predict(mixed_X)

# %%
reconstruction_loss = np.mean((mixed_X - pred)**2, axis=1) # Using MSE as the loss function

# %%
plt.plot(reconstruction_loss[mixed_y==0].to_numpy(), "o", markersize=2, color="darkgreen", label="Normal")
plt.plot(reconstruction_loss[mixed_y==1].to_numpy(), "o", markersize=2, color="darkred", label="Anomaly")
plt.title("Reconstruction Loss")
plt.ylabel("MSE")
plt.xlabel("Test data")
plt.legend()

# %% [markdown]
# The reconstruction loss for the fraud samples are higher than normal samples

# %%
real = reconstruction_loss[mixed_y == 0].to_numpy()
anomaly = reconstruction_loss[mixed_y == 1].to_numpy()

# %%
plt.figure(figsize=(12,5))
plt.subplot(121)
plt.title("Fraud")
plt.hist(anomaly, bins=40, color='r')
plt.subplot(122)
plt.title("Normal")
plt.hist(real, bins=40, color='g')
plt.show()

# %% [markdown]
# Here from the distribution it can be observed that for some fraud samples the loss is near 0

# %%
thresholds = np.arange(0.5, 2, 0.1)
scores = {"recall":[], "f1":[]}
for threshold in thresholds:
    y_pred = [0 if l < threshold else 1 for l in reconstruction_loss]
    scores["recall"].append(recall_score(mixed_y, y_pred))
    scores["f1"].append(f1_score(mixed_y, y_pred))

# %%
fig, axes = plt.subplots(1,2, figsize=(9,4))
axes[0].plot(thresholds, scores["recall"], marker="o", color="dodgerblue")
axes[0].set_xlabel("Thresholds")
axes[0].set_ylabel("Recall")
axes[0].tick_params(which="major", axis="both", labelsize=8)
axes[1].plot(thresholds, scores["f1"], marker="o", color="dodgerblue")
axes[1].set_xlabel("Thresholds")
axes[1].set_ylabel("F1 score")
axes[1].tick_params(which="major", axis="both", labelsize=8)
fig.tight_layout()

# %%
threshold = thresholds[np.argmax(scores["f1"])]

y_pred = [0 if x < threshold else 1 for x in reconstruction_loss]

# %%
print(classification_report(y_true=mixed_y, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.99      0.93       500
#          1.0       0.99      0.84      0.91       425
#
#     accuracy                           0.92       925
#    macro avg       0.93      0.91      0.92       925
# weighted avg       0.93      0.92      0.92       925

# %%
sns.heatmap(confusion_matrix(y_true=mixed_y, y_pred=y_pred), annot=True, cmap="rocket", fmt="g", cbar=False)
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.title("Confusion Matrix")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
model.save('autoencoder.keras')

# %%
tf.keras.backend.clear_session()
